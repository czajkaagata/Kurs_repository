# %%
"""Zadanie 1 – Tworzenie słownika z informacjami o osobie
Stwórz słownik osoba zawierający klucze: imie , nazwisko , wiek , miasto , email .
Wypełnij go przykładowymi danymi i wypisz wszystkie informacje w czytelny sposób.
Wymagania:
Użyj f-stringów do formatowania
Oczekiwany wynik:
(proste)
Wypisz każdą informację w osobnej linii
Wydruk typu: "Imię: Jan, Nazwisko: Kowalski, ..."""
słownik = { 'imie': 'Agata', 'nazwisko': 'Czajka', 'wiek': 90, 'miasto': 'Gdańsk', 'email': 'agata.czajka@example.com' }
print(f"{słownik['imie']})
z_get=słownik.get('nazwisko', 'nie istnieje')
print(f"{z_get}")
# Out:
#   Cell In[6], line 11
#     print(f"{słownik['imie']})
#           ^
# SyntaxError: unterminated f-string literal (detected at line 11)

# %%
Zadanie 2 – Dodawanie i usuwanie elementów ze słownika
Masz słownik z produktami i cenami: {'jabłko': 3.50, 'banan': 2.20, 'pomarańcza':
4.00} . Dodaj nowy produkt 'gruszka': 3.80 , usuń 'banan' , zmień cenę jabłka na
3.20 i wypisz zaktualizowany słownik.
Wymagania:
(proste)
Użyj odpowiednich operacji na słowniku
Wypisz słownik przed i po zmianach

# %%
"""Zadanie 3 – Liczenie wystąpień słów
Masz listę słów: ['python', 'java', 'python', 'javascript', 'python', 'java',
'c++', 'python'] . Policz ile razy każde słowo występuje używając słownika.
Wymagania:
Oczekiwany wynik:
(proste)
Użyj pętli i metody .get()
Wypisz wyniki
Słownik z częstościami: {'python': 4, 'java': 2, ...}"""

słownik = {}
lista = ['python', 'java', 'python', 'javascript', 'python', 'java', 'c++', 'python']
"""for jezyk in lista:
    if jezyk not in slownik:
        słownik[jezyk] = 1
        else:
        słownik[jezyk] += 1"""

for język in lista:
    słownik[język] = słownik.get(język, 0) + 1

print(słownik)
# Out:
# {'python': 4, 'java': 2, 'javascript': 1, 'c++': 1}

# %%
"""✏ Zadanie 9 – Inwersja słownika
Masz słownik mapujący nazwy produktów na kategorie: {'laptop': 'elektronika',
'klawiatura': 'elektronika', 'krzesło': 'meble', 'biurko': 'meble'} . Stwórz
odwrotny słownik gdzie klucze to kategorie, a wartości to listy produktów.
Wymagania:
Oczekiwany wynik:
(średnie)
Iteruj po oryginalnym słowniku
Zgrupuj produkty według kategorii
Wynik: {'elektronika': ['laptop', 'klawiatura'], 'meble': [...]}
Słownik kategoria: lista_produktów
10. ✏ Zadanie 10 – Walidacja danych ze zbiorem dozwolonych wartości
Masz listę kategorii od użytkowników: ['sport', 'muzyka', 'SPORT', 'film', 'xyz',
'nauka', 'gaming'] . Dozwolone kategorie to {'sport', 'muzyka', 'film', 'nauka',
'gry'} . Znajdź nieprawidłowe kategorie (uwzględnij wielkość liter - konwertuj na małe).
Wymagania:
(średnie)
Konwertuj wszystkie kategorie na małe litery
Użyj operacji zbiorowych by znaleźć nieprawidłowe
Wypisz prawidłowe i nieprawidłowe osobno
11. ✏ Zadanie 11 – Dictionary comprehension - kwadraty liczb
Stwórz słownik używając dictionary comprehension, gdzie klucze to liczby od 1 do 20, a
wartości to ich kwadraty. Następnie przefiltruj ten słownik (też comprehension!) by zawierał
tylko liczby parzyste.
Wymagania:
🧠 Zadania wyzwanie (13-20)
Oczekiwany wynik:
(średnie)
Użyj dictionary comprehension 2 razy
Pierwszy słownik: wszystkie liczby 1-20
Drugi słownik: tylko parzyste klucze
Dwa słowniki wypisane

# %%
"""✏ Zadanie 9 – Inwersja słownika
Masz słownik mapujący nazwy produktów na kategorie: {'laptop': 'elektronika',
'klawiatura': 'elektronika', 'krzesło': 'meble', 'biurko': 'meble'} . Stwórz
odwrotny słownik gdzie klucze to kategorie, a wartości to listy produktów.
Wymagania:
Oczekiwany wynik:
(średnie)
Iteruj po oryginalnym słowniku
Zgrupuj produkty według kategorii
Wynik: {'elektronika': ['laptop', 'klawiatura'], 'meble': [...]}
Słownik kategoria: lista_produktów"""
słownik = {'laptop': 'elektronika', 'klawiatura': 'elektronika', 'krzesło': 'meble', 'biurko': 'meble'}
odwrotny = {}   
for produkt, kategoria in słownik.items():
    if kategoria not in odwrotny:
        odwrotny[kategoria] = [produkt]
    else:
        odwrotny[kategoria].append(produkt) 
print(odwrotny)
# Out:
# {'elektronika': ['laptop', 'klawiatura'], 'meble': ['krzesło', 'biurko']}

# %%
"""10. ✏ Zadanie 10 – Walidacja danych ze zbiorem dozwolonych wartości
Masz listę kategorii od użytkowników: ['sport', 'muzyka', 'SPORT', 'film', 'xyz',
'nauka', 'gaming'] . Dozwolone kategorie to {'sport', 'muzyka', 'film', 'nauka',
'gry'} . Znajdź nieprawidłowe kategorie (uwzględnij wielkość liter - konwertuj na małe).
Wymagania:
(średnie)
Konwertuj wszystkie kategorie na małe litery
Użyj operacji zbiorowych by znaleźć nieprawidłowe
Wypisz prawidłowe i nieprawidłowe osobno"""
kategorie_uzytkownikow = {'sport', 'muzyka', 'SPORT', 'film', 'xyz', 'nauka', 'gaming'}
dozwolone_kategorie = {'sport', 'muzyka', 'film', 'nauka', 'gry'}
kategorie_uzytkownikow = set(kategoria.lower() for kategoria in kategorie_uzytkownikow)
nieprawidlowe = kategorie_uzytkownikow - dozwolone_kategorie
prawidlowe = kategorie_uzytkownikow & dozwolone_kategorie
print("Prawidłowe kategorie:", prawidlowe)
print("Nieprawidłowe kategorie:", nieprawidlowe)
# Out:
# Prawidłowe kategorie: {'film', 'muzyka', 'nauka', 'sport'}
# Nieprawidłowe kategorie: {'gaming', 'xyz'}

# %%
"""11. ✏ Zadanie 11 – Dictionary comprehension - kwadraty liczb
Stwórz słownik używając dictionary comprehension, gdzie klucze to liczby od 1 do 20, a
wartości to ich kwadraty. Następnie przefiltruj ten słownik (też comprehension!) by zawierał
tylko liczby parzyste."""
słownik = {x: x**2 for x in range(1, 21)}
parzyste = {k: v for k, v in słownik.items() if k % 2 == 0}
print(słownik)
print(parzyste)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225, 16: 256, 17: 289, 18: 324, 19: 361, 20: 400}
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100, 12: 144, 14: 196, 16: 256, 18: 324, 20: 400}

# %%
"""12. ✏ Zadanie 12 – Analiza transakcji - słowniki zagnieżdżone
Masz listę transakcji (krotek): [('2024-01-15', 'Elektronika', 1200), ('2024-01-
16', 'Meble', 800), ('2024-01-15', 'Elektronika', 350), ...] . Stwórz słownik
gdzie kluczem jest data, a wartością słownik z sumą sprzedaży dla każdej kategorii tego
dnia.
Dataset:
Wymagania:
Oczekiwany wynik:
(średnie)
transakcje = [
('2024-01-15', 'Elektronika', 1200),
('2024-01-15', 'Meble', 450),
('2024-01-16', 'Elektronika', 800),
('2024-01-16', 'Elektronika', 350),
('2024-01-15', 'Odzież', 200),
('2024-01-16', 'Meble', 600)
]
Zagnieżdżone słowniki: {data: {kategoria: suma}}
Iteruj po transakcjach i akumuluj sumy
Słownik typu: {'2024-01-15': {'Elektronika': 1200, 'Meble': 450, ...}, ...} """

transakcje = [
('2024-01-15', 'Elektronika', 1200),    
('2024-01-15', 'Meble', 450),    
('2024-01-16', 'Elektronika', 800),    
('2024-01-16', 'Elektronika', 350),    
('2024-01-15', 'Odzież', 200),    
('2024-01-16', 'Meble', 600)
]
wynik = {}
for data, kategoria, kwota in transakcje:
    if data not in wynik:
        wynik[data] = {}
    if kategoria not in wynik[data]:
        wynik[data][kategoria] = kwota
    else:
        wynik[data][kategoria] += kwota

print(wynik)
# Out:
# {'2024-01-15': {'Elektronika': 1200, 'Meble': 450, 'Odzież': 200}, '2024-01-16': {'Elektronika': 1150, 'Meble': 600}}
